# %%
from splinter import Browser
from bs4 import BeautifulSoup
import re
import pandas as pd
from webdriver_manager.chrome import ChromeDriverManager
from sqlalchemy import create_engine
from config import PGpassword

# %%
executable_path = {'executable_path': ChromeDriverManager().install()}
browser = Browser('chrome', **executable_path, headless=False)
# Out:
# [WDM] - Current google-chrome version is 90.0.4430
# [WDM] - Get LATEST driver version for 90.0.4430
# [WDM] - Get LATEST driver version for 90.0.4430
# [WDM] - Trying to download new driver from http://chromedriver.storage.googleapis.com/90.0.4430.24/chromedriver_win32.zip
# [WDM] - Driver has been saved in cache [C:\Users\ajrfl\.wdm\drivers\chromedriver\win32\90.0.4430.24]

# %%
url = 'https://www.foxnews.com/politics/scott-nevins-tim-scott-uncle-tom-tweet-board-membership'
browser.visit(url)

# %%
html = browser.html
soup = BeautifulSoup(html, 'html.parser')
soup
# Out:
# <html class="cookies geolocation history hashchange no-touchevents fullscreen cssanimations csstransitions" data-n-head="lang" lang="en"><head><script src="https://js-agent.newrelic.com/nr-892.min.js"></script><script src="https://www.googletagservices.com/activeview/js/current/osd.js?cb=%2Fr20100101"></script><script async="" src="https://static.criteo.net/js/ld/publishertag.prebid.js" type="text/javascript"></script><style type="text/css">a.fl_flip_button,a.fl_profile_button{color:#474747;text-decoration:none;display:inline-block;line-height:18px;font-family:'Helvetica Neue',Helvetica,sans-serif;font-size:12px;font-weight:500;text-indent:19px;position:relative;padding-right:5px;background-color:#f0f0f0;border:solid 1px #ccc;height:18px;box-sizing:content-box;-webkit-border-radius:3px;-moz-border-radius:3px;border-radius:3px;background-image:-webkit-linear-gradient(bottom,#dfdfdf,#f7f7f7);background-image:-moz-linear-gradient(bottom,#dfdfdf,#f7f7f7);background-image:-o-linear-gradient(bottom,#dfdfdf,#f7f7f7);background-image:linear-gradient(to top,#dfdfdf,#f7f7f7)}a.fl_flip_button b,a.fl_profile_button b{background:url(data:image/gif;base64,...) no-repeat;background-size:12px 12px;height:12px;width:12px;position:absolute;top:3px;left:3px}a.fl_flip_button:hover,a.fl_profile_button:hover{border-color:#bfbfbf}a.fl_flip_button:active,a.fl_profile_button:active{border:solid 1px #bfbfbf;background-image:-webkit-linear-gradient(top,#dfdfdf,#ebebeb);background-image:-moz-linear-gradient(top,#dfdfdf,#ebebeb);background-image:-o-linear-gradient(top,#dfdfdf,#ebebeb);background-image:linear-gradient(to bottom,#dfdfdf,#ebebeb)}</style>
# <meta content="IE=edge,chrome=1" data-n-head="true" http-equiv="X-UA-Compatible"/><meta content="text/html; charset=utf-8" data-hid="content-type" data-n-head="true" http-equiv="content-type"/><meta content="on" data-hid="x-dns-prefetch-control" data-n-head="true" http-equiv="x-dns-prefetch-control"/><meta charset="utf-8" data-n-head="true"/><meta content="width=device-width, minimum-scale=1.0, initial-scale=1.0" data-hid="viewport" data-n-head="true" name="viewport"/><meta content="en" data-hid="content-language" data-n-head="true" http-equiv="content-language"/><meta content="Comedian Scott Nevins came under fire last week for saying Sen. Tim Scott — who is Black — was “uncle Tom’ing it for his life” during his rebuttal to President Biden’s speech to a joint session of Congress last week." data-hid="description" data-n-head="true" name="description"/><meta content="fnc" data-hid="prism.channel" data-n-head="true" name="prism.channel"/><meta content="politics" data-hid="prism.section" data-n-head="true" name="prism.section"/><meta content="" data-hid="prism.subsection1" data-n-head="true" name="prism.subsection1"/><meta content="" data-hid="prism.subsection2" data-n-head="true" name="prism.subsection2"/><meta content="" data-hid="prism.subsection3" data-n-head="true" name="prism.subsection3"/><meta content="" data-hid="prism.subsection4" data-n-head="true" name="prism.subsection4"/><meta content="subsection" data-hid="prism.aggregationType" data-n-head="true" name="prism.aggregationType"/><meta content="" data-hid="prism.genre" data-n-head="true" name="prism.genre"/><meta content="article" data-hid="pagetype" data-n-head="true" name="pagetype"/><meta content="tiger" data-hid="content-creator" data-n-head="true" name="content-creator"/><meta content="Houston Keene" data-hid="dc.creator" data-n-head="true" name="dc.creator" scheme="dcterms.creator"/><meta content="Comedian scrubs board membership from social media bios after racist tweet targeting Tim Scott" data-hid="dc.title" data-n-head="true" name="dc.title"/><meta content="" data-hid="dc.subject" data-n-head="true" name="dc.subject"/><meta content="Comedian Scott Nevins came under fire last week for saying Sen. Tim Scott — who is Black — was “uncle Tom’ing it for his life” during his rebuttal to President Biden’s speech to a joint session of Congress last week." data-hid="dcterms.abstract" data-n-head="true" name="dcterms.abstract"/><meta content="Text.Article" data-hid="dc.type" data-n-head="true" name="dc.type" scheme="dcterms.DCMIType"/><meta content="Comedian Scott Nevins came under fire last week for saying Sen. Tim Scott — who is Black — was “uncle Tom’ing it for his life” during his rebuttal to President Biden’s speech to a joint session of Congress last week." data-hid="dc.description" data-n-head="true" name="dc.description"/><meta content="en-US" data-hid="dc.language" data-n-head="true" name="dc.language" scheme="dcterms.RFC4646"/><meta content="Fox News" data-hid="dc.publisher" data-n-head="true" name="dc.publisher"/><meta content="text/html" data-hid="dc.format" data-n-head="true" name="dc.format" scheme="dcterms.IMT"/><meta content="urn:uri:base64:028fa6df-c59b-515d-8d12-e7b4f149f24f" data-hid="dc.identifier" data-n-head="true" name="dc.identifier" scheme="dcterms.URI"/><meta content="Fox News" data-hid="dc.source" data-n-head="true" name="dc.source"/><meta content="2021-05-03" data-hid="dc.date" data-n-head="true" name="dc.date"/><meta content="2021-05-03T12:29:37-04:00" data-hid="dcterms.created" data-n-head="true" name="dcterms.created" scheme="dcterms.ISO8601"/><meta content="2021-05-03T14:06:56-04:00" data-hid="dcterms.modified" data-n-head="true" name="dcterms.modified" scheme="dcterms.ISO8601"/><meta content="Comedian scrubs board membership from social media bios after racist tweet targeting Tim Scott" data-hid="og:title" data-n-head="true" property="og:title"/><meta content="Comedian Scott Nevins came under fire last week for saying Sen. Tim Scott —  ...
#       {
#         "@context": "http://schema.org",
#         "@type": "NewsArticle",
#         "mainEntityOfPage": "https://www.foxnews.com/politics/scott-nevins-tim-scott-uncle-tom-tweet-board-membership",
#         "headline": "Comedian scrubs board membership from social media bios after racist tweet targeting Tim Scott",
#         "datePublished": "2021-05-03T14:06:56-04:00",
#         "dateModified": "2021-05-03T14:06:56-04:00",
#         "description": "Comedian Scott Nevins came under fire last week for saying Sen. Tim Scott — who is Black — was “uncle Tom’ing it for his life” during his rebuttal to President Biden’s speech to a joint session of Congress last week.",
#         "author": {
#           "@type": "Person",
#           "name": "Houston Keene"
#         },
#         "publisher": {
#           "@type": "Organization",
#           "name": "Fox News",
#           "logo": {
#             "@type": "ImageObject",
#             "url": "https://static.foxnews.com/static/orion/styles/img/fox-news/amp/fox-news-logo.png",
#             "width": 133,
#             "height": 60
#           }
#         },
#         "image": {
#           "@type": "ImageObject",
#           "url": "https://a57.foxnews.com/static.foxnews.com/foxnews.com/content/uploads/2021/04/1200/675/GettyImages-1228804366.jpg?ve=1&tl=1",
#           "width": 1200,
#           "height": 675
#         }
#       }
#     </script><script data-n-head="true" type="application/ld+json">
#       {
#         "@context": "http://schema.org/",
#         "@type": "WebPage",
#         "name": "Comedian scrubs board membership from social media bios after racist tweet targeting Tim Scott",
#         "speakable": {"@type": "SpeakableSpecification","cssSelector": [".head1", ".speakable"]},
#         "url": "https://www.foxnews.com/politics/scott-nevins-tim-scott-uncle-tom-tweet-board-membership"
#       }
#     </script><script data-n-head="true" src="//static.foxnews.com/static/orion/scripts/core/pages/articles.new/loader.js"></script><link as="script" href="/_wzln/manifest.0067eddf7c50f6066929.js" rel="preload"/><link as="script" href="/_wzln/vendor.701e213e9767aae07a01.js" rel="preload"/><link as="script" href="/_wzln/app.7cd331939569e948bbe8.js" rel="preload"/><link href="/_wzln/pages/_slug/_article.863a49e69b64c754afac.js" rel="prefetch"/><link href="/_wzln/pages/category/_slug.b2f3a24eff44dd728869.js" rel="prefetch"/><link href="/_wzln/layouts/dynamic-route.6a2696f78d934d486590.js" rel="prefetch"/><link href="/_wzln/pages/search-results/search.91cae487dcb5113b5487.js" rel="prefetch"/><link href="/_wzln/pages/shows/_id.afcfe79a0b26fb78d23f.js" rel="prefetch"/><link href="/_wzln/pages/person/_p/_slug/index.91dad430da73b34f5523.js" rel="prefetch"/><link href="/_wzln/pages/personalities/index.8d9b9b7764380a6b2c3b.js" rel="prefetch"/><link href="/_wzln/pages/fnctv/index.f07e7c685ccfd5e5c8d3.js" rel="prefetch"/><link href="/_wzln/pages/newyears/index.6be2abda939ca9f0b59a.js" rel="prefetch"/><link href="/_wzln/pages/shows/index.b3b666eca4deb9e07bf8.js" rel="prefetch"/><link href="/_wzln/pages/person/personalities/index.db8e8b160910c5959110.js" rel="prefetch"/><link href="/_wzln/pages/gowatch/index.d52869f52ad48c46e566.js" rel="prefetch"/><link href="/_wzln/pages/go/index.5f0da148022e1bf64d9c.js" rel="prefetch"/><link href="/_wzln/pages/foxaroundtheworld/search/index.3dca05ed70e342c8c457.js" rel="prefetch"/><link href="/_wzln/pages/foxaroundtheworld/index.c78461a819d891025131.js" rel="prefetch"/><link href="/_wzln/pages/coverage/_page.40a55eab62989417f763.js" rel="prefetch"/><link href="/_wzln/pages/alerts/subscribe/index.e9c6ec3c02fbf2d4051e.js" rel="prefetch"/><link href="/_wzln/layouts/static-pages-personalities.1be09ed60172dc167f55.js" rel="prefetch"/><link href="/_wzln/layouts/shows.f5913afd5003fb739aac.js" rel="prefetch"/><link href="/_wzln/layouts/search-page.647e112601d71ea670f9.js" rel="prefetch"/><link href="/_wzln/layouts/persons.703bf4a659c29e60881f.js" rel="prefetch"/><link href="/_wzln/layouts/newyears.5bcf73e4553126d439f8.js" rel="prefetch"/><link href="/_wzln/layouts/live-event-page.ffa2ac343d76f00da3a6.js" rel="prefetch"/><link href="/_wzln/layouts/fnctv.f9b90e7030ca43712710.js" rel="prefetch"/><link href="/_wzln/layouts/error-page.9f536e862ad744b5ab73.js" rel="prefetch"/><link href="/_wzln/layouts/dynamic-layouts/static-pages.32b4a5e5903e052555a3.js" rel="prefetch"/><link href="/_wzln/layouts/dynamic-layouts/show-layout.6bd60e8bc09434f7d6ea.js" rel="prefetch"/><link href="/_wzln/layouts/dynamic-layouts/section-pages.8176bd70ccffb756cca3.js" rel="prefetch"/><link href="/_wzln/layouts/dynamic-layouts/person-layout.6545e161846f9f7cef9a.js" rel="prefetch"/><link href="/_wzln/layouts/dynamic-layouts/article-pages.e4d3a9b9afa00f43bcef.js" rel="prefetch"/><link href="/_wzln/layouts/category.cd267cce55a2c6497d02.js" rel="prefetch"/><link href="/_wzln/pages/index.5b4a38e1c3b92230dab8.js" rel="prefetch"/><link href="/_wzln/layouts/default.2d9ec14481eee86eb0ff.js" rel="prefetch"/><style data-vue-ssr-id="08be192a:0">.video-player[data-v-34380c3f]{width:100%;height:100%}</style>
# <script>(window.BOOMR_mq=window.BOOMR_mq||[]).push(["addVar",{"rua.upush":"false","rua.cpush":"true","rua.upre":"false","rua.cpre":"false","rua.uprl":"false","rua.cprl":"false","rua.cprf":"false","rua.trans":"SJ-ca6d0bf2-293a-4c02-9518-0365446eb004","rua.cook":"false","rua.ims":"false","rua.ufprl":"false","rua.cfprl":"false","rua.isuxp":"","rua.texp":""}]);</script>
# <script>!function(a){var e="https://s.go-mpulse.net/boomerang/",t="addEventListener";if("False"=="True")a.BOOMR_config=a.BOOMR_config||{},a.BOOMR_config.PageParams=a.BOOMR_config.PageParams||{},a.BOOMR_config.PageParams.pci=!0,e="https://s2.go-mpulse.net/boomerang/";if(window.BOOMR_API_key="5GX6Z-TSK3U-2BF75-P7PTZ-QMLZM",function(){function n(e){a.BOOMR_onload=e&&e.timeStamp||(new Date).getTime()}if(!a.BOOMR||!a.BOOMR.version&&!a.BOOMR.snippetExecuted){a.BOOMR=a.BOOMR||{},a.BOOMR.snippetExecuted=!0;var i,_,o,r=document.createElement("iframe");if(a[t])a[t]("load",n,!1);else if(a.attachEvent)a.attachEvent("onload",n);r.src="javascript:void(0)",r.title="",r.role="presentation",(r.frameElement||r).style.cssText="width:0;height:0;border:0;display:none;",o=document.getElementsByTagName("script")[0],o.parentNode.insertBefore(r,o);try{_=r.contentWindow.document}catch(O){i=document.domain,r.src="javascript:var d=document.open();d.domain='"+i+"';void(0);",_=r.contentWindow.document}_.open()._l=function(){var a=this.createElement("script");if(i)this.domain=i;a.id="boomr-if-as",a.src=e+"5GX6Z-TSK3U-2BF75-P7PTZ-QMLZM",BOOMR_lstart=(new Date).getTime(),this.body.appendChild(a)},_.write("<bo"+'dy onload="document._l();">'),_.close()}}(),"".length>0)if(a&&"performance"in a&&a.performance&&"function"==typeof a.performance.setResourceTimingBufferSize)a.performance.setResourceTimingBufferSize();!function(){if(BOOMR=a.BOOMR||{},BOOMR.plugins=BOOMR.plugins||{},!BOOMR.plugins.AK){var e="true"=="true"?1:0,t="",n="eyaqmrwcaaoxajqacqdaapadvjqjdy27-f-a5375a19e-clienttons-s.akamaihd.net",i={"ak.v":"31","ak.cp":"218742","ak.ai":parseInt("177077",10),"ak.ol":"0","ak.cr":57,"ak.ipv":6,"ak.proto":"http/1.1","ak.rid":"898a21f","ak.r":34123,"ak.a2":e,"ak.m":"dsca","ak.n":"essl","ak.bpcip":"2601:646:c200:1d70::","ak.cport":57817,"ak.gh":"184.25.254.86","ak.quicv":"","ak.tlsv":"tls1.3","ak.0rtt":"","ak.csrc":"-","ak.acc":"reno","ak.t":"1620173663","ak.ak":"hOBiQwZUYzCg5VSAfCLimQ==...","ak.pv":"810","ak.dpoabenc":""};if(""!==t)i["ak.ruds"]=t;var _={i:!1,av:function(e){var t="http.initiator";if(e&&(!e[t]||"spa_hard"===e[t]))i["ak.feo"]=void 0!==a.aFeoApplied?1:0,BOOMR.addVar(i)},rv:function(){var a=["ak.bpcip","ak.cport","ak.cr","ak.csrc","ak.gh","ak.ipv","ak.m","ak.n","ak.ol","ak.proto","ak.quicv","ak.tlsv","ak.0rtt","ak.r","ak.acc","ak.t"];BOOMR.removeVar(a)}};BOOMR.plugins.AK={akVars:i,akDNSPreFetchDomain:n,init:function(){if(!_.i){var a=BOOMR.subscribe;a("before_beacon",_.av,null,null),a("onbeacon",_.rv,null,null),_.i=!0}return this},is_complete:function(){return!0}}}}()}(window);</script><script async="" src="https://webcontentassessor.global.ssl.fastly.net/scripts/7f6b47b885c961c1893a3d523de9cb646a29c46d8c1dd1a4259600d3e3ea5242" type="text/javascript"></script><script async="" defer="" src="https://static.foxnews.com/static/leap/core.js"></script><script async="" defer="" src="//www.googletagmanager.com/gtag/js?id=AW-780970426"></script><script async="" defer="" src="https://static.foxnews.com/static/isa/app/lib/bing.js"></script><script async="" defer="" src="//static.criteo.net/js/ld/ld.js"></script><script async="" defer="" src="https://static.foxnews.com/static/isa/app/lib/permutive.js"></script><script async="" crossorigin="anonymous" defer="" src="//player.h-cdn.com/loader.js?customer=foxnews"></script><script async="" defer="" src="https://static.foxnews.com/static/isa/app/lib/lytics.js"></script><script async="" src="https://tagger.opecloud.com/fox/v2/tagger.js" type="text/javascript"></script><script async="" charset="utf-8" src="/_wzln/pages/_slug/_article.863a49e69b64c754afac.js" type="text/javascript"></script><script async="" charset="utf-8" data-modulr-context="fox.strike" data-modulr-module="lodash" src="https://static.foxnews.com/static/strike/scripts/libs/lodash.js?v=v23" type="text/javascript"></script><script async="" charset="utf-8" data-modulr-context="leap.metrics" data-modulr-module="util.lodash" src="https://static.foxnews.com/static ...
#     color: #666666;
# }
# #spcv_conversation#spcv_conversation .spcv_rich-editor .spcv_rich-editor-container {
#     border: thin solid #666666 !important;
# }
# #spcv_conversation#spcv_conversation .spcv_animated-vote .spcv_vote-icon.spcv_inactive {
#     fill: #666666 !important;
# }
# #spcv_conversation#spcv_conversation .spcv_notifications .spcv_indicator .spcv_icon {
# fill: #666666 !important;
# color: #666666 !important;
# }
#
# #spcv_conversation#spcv_conversation .spcv_notifications .spcv_indicator .spcv_icon:hover {
# fill: #666666 !important;
# color: #666666 !important;
# }
#
# #spcv_conversation#spcv_conversation .spcv_show-more-replies .spcv_show-more-replies-button {
# color: #666666;
# }
# #spcv_conversation#spcv_conversation .spcv_footer-link, #spcv_conversation#spcv_conversation .spcv_site-link  {
# color: #666666;
# }
# #spcv_conversation#spcv_conversation .spcv_location {
#      color: #666666;
# }
# #spcv_conversation#spcv_conversation .spcv_message-reply , #spcv_conversation#spcv_conversation .spcv_message-share-link , #spcv_conversation#spcv_conversation .spcv_down-votes, #spcv_conversation#spcv_conversation .spcv_up-votes, #spcv_conversation#spcv_conversation .spcv_votes-count,#spcv_conversation#spcv_conversation .spcv_message-report {
#      color: #666666;
# }
# #spcv_conversation#spcv_conversation .spcv_message-details , #spcv_conversation#spcv_conversation .spcv_message-details .spcv_reply-to .spcv_username{
#      color: #666666;
# }
#
#
# #spcv_conversation#spcv_conversation .spcv_notifications .spcv_indicator.spcv_active .spcv_icon, #spcv_conversation#spcv_conversation .spcv_notifications .spcv_indicator:hover .spcv_icon {
# fill: #666666 !important;
# }
#
# #spcv_conversation#spcv_conversation .spcv_sort-menu {
#      color: #666666;
# }
# #spcv_conversation#spcv_conversation .spcv_sort-menu .spcv_sort-by {
#      color: #666666;
# }
# #spcv_conversation#spcv_conversation .spcv_current-user-menu.spcv_text-trigger .spcv_wrapper>* {
#     color: #666666;
# }
# #spcv_conversation#spcv_conversation .spcv_badge {
#   color: #666666 !important;
# };
#
# [data-spot-im-class="set-moderation-item"] {
#     display: none !important;
# };
#
# [data-spot-im-class="settings-item"]{
# 		display: none !important;
# };
#
# [data-spot-im-class="rich-editor-send-button"] span{
#  pointer-events:none;
# };
#
# #root > div > div.user-profile-modal.modal-wrap > div > div.top-navigation > div > div.user-menu > div.tooltip.open.user-dropdown > div > ul > li:nth-child(2){
# 	    display: none !important;
# };
#
# 	/* cyrillic-ext */
# @font-face {
# font-family: 'Roboto';
# font-style: normal;
# font-weight: 400;
# src: local('Roboto'), local('Roboto-Regular'), url(https://fonts.gstatic.com/s/roboto/v16/sTdaA6j0Psb920Vjv-mrzH-_kf6ByYO6CLYdB4HQE-Y.woff2) format('woff2');
# unicode-range: U+0460-052F, U+20B4, U+2DE0-2DFF, U+A640-A69F;
# }
# /* cyrillic */
# @font-face {
# font-family: 'Roboto';
# font-style: normal;
# font-weight: 400;
# src: local('Roboto'), local('Roboto-Regular'), url(https://fonts.gstatic.com/s/roboto/v16/uYECMKoHcO9x1wdmbyHIm3-_kf6ByYO6CLYdB4HQE-Y.woff2) format('woff2');
# unicode-range: U+0400-045F, U+0490-0491, U+04B0-04B1, U+2116;
# }
# /* greek-ext */
# @font-face {
# font-family: 'Roboto';
# font-style: normal;
# font-weight: 400;
# src: local('Roboto'), local('Roboto-Regular'), url(https://fonts.gstatic.com/s/roboto/v16/tnj4SB6DNbdaQnsM8CFqBX-_kf6ByYO6CLYdB4HQE-Y.woff2) format('woff2');
# unicode-range: U+1F00-1FFF;
# }
# /* greek */
# @font-face {
# font-family: 'Roboto';
# font-style: normal;
# font-weight: 400;
# src: local('Roboto'), local('Roboto-Regular'), url(https://fonts.gstatic.com/s/roboto/v16/_VYFx-s824kXq_Ul2BHqYH-_kf6ByYO6CLYdB4HQE-Y.woff2) format('woff2');
# unicode-range: U+0370-03FF;
# }
# /* vietnamese */
# @font-face {
# font-family: 'Roboto';
# font-style: normal;
# font-weight: 400;
# src: local('Roboto'), local('Roboto-Regular'), url(https://fonts.gstatic.com/s/roboto/v16/NJ4vxlgWwWbEsv18dAhqnn-_kf6ByYO6CLYdB4HQE-Y.woff2) format('woff2');
# unicode-range: U+0102-0103, U+1EA0-1EF9, U+20AB;
# }
# /* latin-ext */
# @font-face {
# font-family: 'Roboto';
# font-style: normal;
# font-weight: 400;
# src: local('Roboto'), local('Roboto-Regular'), url(https://fonts.gstatic.com/s/roboto/v16/Ks_cVxiCiwUWVsFWFA3Bjn-_kf6ByYO6CLYdB4HQE-Y.woff2) format('woff2');
# unicode-range: U+0100-024F, U+1E00-1EFF, U+20A0-20AB, U+20AD-20CF, U+2C60-2C7F, U+A720-A7FF;
# }
# /* latin */
# @font-face {
# font-family: 'Roboto';
# font-style: normal;
# font-weight: 400;
# src: local('Roboto'), local('Roboto-Regular'), url(https://fonts.gstatic.com/s/roboto/v16/oMMgfZMQthOryQo9n22dcuvvDin1pK8aKteLpeZ5c0A.woff2) format('woff2');
# unicode-range: U+0000-00FF, U+0131, U+0152-0153, U+02C6, U+02DA, U+02DC, U+2000-206F, U+2074, U+20AC, U+2212, U+2215;
# }
# /* cyrillic-ext */
# @font-face {
# font-family: 'Roboto';
# font-style: normal;
# font-weight: 700;
# src: local('Roboto Bold'), local('Roboto-Bold'), url(https://fonts.gstatic.com/s/roboto/v16/77FXFjRbGzN4aCrSFhlh3oX0hVgzZQUfRDuZrPvH3D8.woff2) format('woff2');
# unicode-range: U+0460-052F, U+20B4, U+2DE0-2DFF, U+A640-A69F;
# }
# /* cyrillic */
# @font-face {
# font-family: 'Roboto';
# font-style: normal;
# font-weight: 700;
# src: local('Roboto Bold'), local('Roboto-Bold'), url(https://fonts.gstatic.com/s/roboto/v16/isZ-wbCXNKAbnjo6_TwHToX0hVgzZQUfRDuZrPvH3D8.woff2) format('woff2');
# unicode-range: U+0400-045F, U+0490-0491, U+04B0-04B1, U+2116;
# }
# /* greek-ext */
# @font-face {
# font-family: 'Roboto';
# font-style: normal;
# font-weight: 700;
# src: local('Roboto Bold'), local('Roboto-Bold'), url(https://fonts.gstatic.com/s/roboto/v16/UX6i4JxQDm3fVTc1CPuwqoX0hVgzZQUfRDuZrPvH3D8.woff2) format('woff2');
# unicode-range: U+1F00-1FFF;
# }
# /* greek */
# @font-face {
# font-family: 'Roboto';
# font-style: normal;
# font-weight: 700;
# src: local('Roboto Bold'), local('Roboto-Bold'), url(https://fonts.gstatic.com/s/roboto/v16/jSN2CGVDbcVyCnfJfjSdfIX0hVgzZQUfRDuZrPvH3D8.woff2) format('woff2');
# unicode-range: U+0370-03FF;
# }
# /* vietnamese */
# @font-face {
# font-family: 'Roboto';
# font-style: normal;
# font-weight: 700;
# src: local('Roboto Bold'), local('Roboto-Bold'), url(https://fonts.gstatic.com/s/roboto/v16/PwZc-YbIL414wB9rB1IAPYX0hVgzZQUfRDuZrPvH3D8.woff2) format('woff2');
# unicode-range: U+0102-0103, U+1EA0-1EF9, U+20AB;
# }
# /* latin-ext */
# @font-face {
# font-family: 'Roboto';
# font-style: normal;
# font-weight: 700;
# src: local('Roboto Bold'), local('Roboto-Bold'), url(https://fonts.gstatic.com/s/roboto/v16/97uahxiqZRoncBaCEI3aW4X0hVgzZQUfRDuZrPvH3D8.woff2) format('woff2');
# unicode-range: U+0100-024F, U+1E00-1EFF, U+20A0-20AB, U+20AD-20CF, U+2C60-2C7F, U+A720-A7FF;
# }
# /* latin */
# @font-face {
# font-family: 'Roboto';
# font-style: normal;
# font-weight: 700;
# src: local('Roboto Bold'), local('Roboto-Bold'), url(https://fonts.gstatic.com/s/roboto/v16/d-6IYplOFocCacKzxwXSOJBw1xU1rKptJj_0jans920.woff2) format('woff2');
# unicode-range: U+0000-00FF, U+0131, U+0152-0153, U+02C6, U+02DA, U+02DC, U+2000-206F, U+2074, U+20AC, U+2212, U+2215;
# }
# .modal-frame, .modal-frame * {
#   font-family: Roboto, Open Sans, Helvetica, Arial, sans-serif !important;
# }
# div.user-profile-modal.modal-wrap > div > div.profile-preview.scrollable-wrap .edit-box.edit-user-settings .input-field:nth-child(3) {
# 	display: none;
# }
# div.user-profile-modal.modal-wrap > div > div.profile-preview.scrollable-wrap > div > div > div.edit-box.edit-user-profile > div:nth-child(1){
# 	display: none;
# }
#
# 		[data-spot-im-class="conversation-root"], [data-spot-im-class="conversation-root"] * {
#     font-family: Roboto, Open Sans, Helvetica, Arial, sans-serif !important;
# }
#
# @media screen and (max-width: 290px) {
#         /*IPhone portrait and smaller. You can probably stop on 380px*/
#        .spcv_message-actions-container .spcv_message-actions {
#             flex-wrap: wrap;
#             width: 125px;
#         }
#         [data-spot-im-class="vote-links"] {
#             margin-top: 10px;
#  }
#  [data-spot-im-class="message-share-button"] {
#           display: none;
#   }
# .spcv_message-actions {
#        flex-wrap: wrap;
# }
# }
# </style><link crossorigin="use-credentials" href="https://api-2-0.spot.im" rel="preconnect"/><link crossorigin="use-credentials" href="https://static-cdn.spot.im" rel="preconnect"/><style data-spot-im-style="true" data-spot-im-style-module="@spotim/launcher" data-spot-im-style-module-version="v2.53.5">@keyframes spotim-dom-attachment-animation { from {} to {} }
#     [data-spotim-module]:not([data-ready="true"]) { animation: spotim-dom-attachment-animation 1ms; }</style><link as="script" href="https://adservice.google.com/adsid/integrator.js?domain=www.foxnews.com" rel="preload"/><script src="https://adservice.google.com/adsid/integrator.js?domain=www.foxnews.com" type="text/javascript"></script><link href="https://26c69e6306f11d86cddee2ce6f32d5ae.safeframe.googlesyndication.com/safeframe/1-0-38/html/container.html" rel="prefetch"/><link href="https://tpc.googlesyndication.com/safeframe/1-0-38/html/container.html" rel="prefetch"/><script charset="utf-8" src="https://static-cdn.spot.im/production/registration/tags/v1.15.5/vendors~main-bootstrap~registration-disqus-login~registration-logout~registration-start-sso~registra~5961887e-bundle.js"></script><script charset="utf-8" src="https://static-cdn.spot.im/production/registration/tags/v1.15.5/registration-logout-bundle.js"></script><link as="script" href="https://adservice.google.com/adsid/integrator.js?domain=www.foxnews.com" rel="preload"/><script src="https://adservice.google.com/adsid/integrator.js?domain=www.foxnews.com" type="text/javascript"></script><style data-spot-im-style="true" data-spot-im-style-module="@spotim/launcher" data-spot-im-style-module-version="v2.53.5">@keyframes spotim-dom-attachment-animation { from {} to {} }
#     [data-spot-im-shadow-host] { animation: spotim-dom-attachment-animation 1ms; }</style><style data-spot-im-style="true" data-spot-im-style-module="*">  [data-spotim-module="conversation"]:not([data-spotim-not-for-self-bootstrapping]), [data-spotim-module="liveblog"] {    animation: spotim-detector-animation--1438572233 1ms !important;  }    @keyframes spotim-detector-animation--1438572233 {    from {    } to {    }  }  </style><style data-spot-im-style="true" data-spot-im-style-module="*">  [data-spot-im-module-default-area="conversation"], [data-spot-im-module-default-area="liveblog"] {    animation: spotim-detector-animation--706399726 1ms !important;  }    @keyframes spotim-detector-animation--706399726 {    from {    } to {    }  }  </style><link data-spot-im-style="true" data-spot-im-style-module="conversation" data-spot-im-style-module-version="v3.33.14" href="https://static-cdn.spot.im/production/conversation/tags/v3.33.14/styles.css" rel="stylesheet" type="text/css"/><style type="text/css"></style><style type="text/css">#spcv_conversation#spcv_conversation textarea::placeholder {
#     color: #666666;
# }
# #spcv_conversation#spcv_conversation .spcv_rich-editor .spcv_rich-editor-container {
#     border: thin solid #666666 !important;
# }
# #spcv_conversation#spcv_conversation .spcv_animated-vote .spcv_vote-icon.spcv_inactive {
#     fill: #666666 !important;
# }
# #spcv_conversation#spcv_conversation .spcv_notifications .spcv_indicator .spcv_icon {
# fill: #666666 !important;
# color: #666666 !important;
# }
#
# #spcv_conversation#spcv_conversation .spcv_notifications .spcv_indicator .spcv_icon:hover {
# fill: #666666 !important;
# color: #666666 !important;
# }
#
# #spcv_conversation#spcv_conversation .spcv_show-more-replies .spcv_show-more-replies-button {
# color: #666666;
# }
# #spcv_conversation#spcv_conversation .spcv_footer-link, #spcv_conversation#spcv_conversation .spcv_site-link  {
# color: #666666;
# }
# #spcv_conversation#spcv_conversation .spcv_location {
#      color: #666666;
# }
# #spcv_conversation#spcv_conversation .spcv_message-reply , #spcv_conversation#spcv_conversation .spcv_message-share-link , #spcv_conversation#spcv_conversation .spcv_down-votes, #spcv_conversation#spcv_conversation .spcv_up-votes, #spcv_conversation#spcv_conversation .spcv_votes-count,#spcv_conversation#spcv_conversation .spcv_message-report {
#      color: #666666;
# }
# #spcv_conversation#spcv_conversation .spcv_message-details , #spcv_conversation#spcv_conversation .spcv_message-details .spcv_reply-to .spcv_username{
#      color: #666666;
# }
#
#
# #spcv_conversation#spcv_conversation .spcv_notifications .spcv_indicator.spcv_active .spcv_icon, #spcv_conversation#spcv_conversation .spcv_notifications .spcv_indicator:hover .spcv_icon {
# fill: #666666 !important;
# }
#
# #spcv_conversation#spcv_conversation .spcv_sort-menu {
#      color: #666666;
# }
# #spcv_conversation#spcv_conversation .spcv_sort-menu .spcv_sort-by {
#      color: #666666;
# }
# #spcv_conversation#spcv_conversation .spcv_current-user-menu.spcv_text-trigger .spcv_wrapper>* {
#     color: #666666;
# }
# #spcv_conversation#spcv_conversation .spcv_badge {
#   color: #666666 !important;
# };
#
# [data-spot-im-class="set-moderation-item"] {
#     display: none !important;
# };
#
# [data-spot-im-class="settings-item"]{
# 		display: none !important;
# };
#
# [data-spot-im-class="rich-editor-send-button"] span{
#  pointer-events:none;
# };
#
# #root > div > div.user-profile-modal.modal-wrap > div > div.top-navigation > div > div.user-menu > div.tooltip.open.user-dropdown > div > ul > li:nth-child(2){
# 	    display: none !important;
# };
#
# 	/* cyrillic-ext */
# @font-face {
# font-family: 'Roboto';
# font-style: normal;
# font-weight: 400;
# src: local('Roboto'), local('Roboto-Regular'), url(https://fonts.gstatic.com/s/roboto/v16/sTdaA6j0Psb920Vjv-mrzH-_kf6ByYO6CLYdB4HQE-Y.woff2) format('woff2');
# unicode-range: U+0460-052F, U+20B4, U+2DE0-2DFF, U+A640-A69F;
# }
# /* cyrillic */
# @font-face {
# font-family: 'Roboto';
# font-style: normal;
# font-weight: 400;
# src: local('Roboto'), local('Roboto-Regular'), url(https://fonts.gstatic.com/s/roboto/v16/uYECMKoHcO9x1wdmbyHIm3-_kf6ByYO6CLYdB4HQE-Y.woff2) format('woff2');
# unicode-range: U+0400-045F, U+0490-0491, U+04B0-04B1, U+2116;
# }
# /* greek-ext */
# @font-face {
# font-family: 'Roboto';
# font-style: normal;
# font-weight: 400;
# src: local('Roboto'), local('Roboto-Regular'), url(https://fonts.gstatic.com/s/roboto/v16/tnj4SB6DNbdaQnsM8CFqBX-_kf6ByYO6CLYdB4HQE-Y.woff2) format('woff2');
# unicode-range: U+1F00-1FFF;
# }
# /* greek */
# @font-face {
# font-family: 'Roboto';
# font-style: normal;
# font-weight: 400;
# src: local('Roboto'), local('Roboto-Regular'), url(https://fonts.gstatic.com/s/roboto/v16/_VYFx-s824kXq_Ul2BHqYH-_kf6ByYO6CLYdB4HQE-Y.woff2) format('woff2');
# unicode-range: U+0370-03FF;
# }
# /* vietnamese */
# @font-face {
# font-family: 'Roboto';
# font-style: normal;
# font-weight: 400;
# src: local('Roboto'), local('Roboto-Regular'), url(https://fonts.gstatic.com/s/roboto/v16/NJ4vxlgWwWbEsv18dAhqnn-_kf6ByYO6CLYdB4HQE-Y.woff2) format('woff2');
# unicode-range: U+0102-0103, U+1EA0-1EF9, U+20AB;
# }
# /* latin-ext */
# @font-face {
# font-family: 'Roboto';
# font-style: normal;
# font-weight: 400;
# src: local('Roboto'), local('Roboto-Regular'), url(https://fonts.gstatic.com/s/roboto/v16/Ks_cVxiCiwUWVsFWFA3Bjn-_kf6ByYO6CLYdB4HQE-Y.woff2) format('woff2');
# unicode-range: U+0100-024F, U+1E00-1EFF, U+20A0-20AB, U+20AD-20CF, U+2C60-2C7F, U+A720-A7FF;
# }
# /* latin */
# @font-face {
# font-family: 'Roboto';
# font-style: normal;
# font-weight: 400;
# src: local('Roboto'), local('Roboto-Regular'), url(https://fonts.gstatic.com/s/roboto/v16/oMMgfZMQthOryQo9n22dcuvvDin1pK8aKteLpeZ5c0A.woff2) format('woff2');
# unicode-range: U+0000-00FF, U+0131, U+0152-0153, U+02C6, U+02DA, U+02DC, U+2000-206F, U+2074, U+20AC, U+2212, U+2215;
# }
# /* cyrillic-ext */
# @font-face {
# font-family: 'Roboto';
# font-style: normal;
# font-weight: 700;
# src: local('Roboto Bold'), local('Roboto-Bold'), url(https://fonts.gstatic.com/s/roboto/v16/77FXFjRbGzN4aCrSFhlh3oX0hVgzZQUfRDuZrPvH3D8.woff2) format('woff2');
# unicode-range: U+0460-052F, U+20B4, U+2DE0-2DFF, U+A640-A69F;
# }
# /* cyrillic */
# @font-face {
# font-family: 'Roboto';
# font-style: normal;
# font-weight: 700;
# src: local('Roboto Bold'), local('Roboto-Bold'), url(https://fonts.gstatic.com/s/roboto/v16/isZ-wbCXNKAbnjo6_TwHToX0hVgzZQUfRDuZrPvH3D8.woff2) format('woff2');
# unicode-range: U+0400-045F, U+0490-0491, U+04B0-04B1, U+2116;
# }
# /* greek-ext */
# @font-face {
# font-family: 'Roboto';
# font-style: normal;
# font-weight: 700;
# src: local('Roboto Bold'), local('Roboto-Bold'), url(https://fonts.gstatic.com/s/roboto/v16/UX6i4JxQDm3fVTc1CPuwqoX0hVgzZQUfRDuZrPvH3D8.woff2) format('woff2');
# unicode-range: U+1F00-1FFF;
# }
# /* greek */
# @font-face {
# font-family: 'Roboto';
# font-style: normal;
# font-weight: 700;
# src: local('Roboto Bold'), local('Roboto-Bold'), url(https://fonts.gstatic.com/s/roboto/v16/jSN2CGVDbcVyCnfJfjSdfIX0hVgzZQUfRDuZrPvH3D8.woff2) format('woff2');
# unicode-range: U+0370-03FF;
# }
# /* vietnamese */
# @font-face {
# font-family: 'Roboto';
# font-style: normal;
# font-weight: 700;
# src: local('Roboto Bold'), local('Roboto-Bold'), url(https://fonts.gstatic.com/s/roboto/v16/PwZc-YbIL414wB9rB1IAPYX0hVgzZQUfRDuZrPvH3D8.woff2) format('woff2');
# unicode-range: U+0102-0103, U+1EA0-1EF9, U+20AB;
# }
# /* latin-ext */
# @font-face {
# font-family: 'Roboto';
# font-style: normal;
# font-weight: 700;
# src: local('Roboto Bold'), local('Roboto-Bold'), url(https://fonts.gstatic.com/s/roboto/v16/97uahxiqZRoncBaCEI3aW4X0hVgzZQUfRDuZrPvH3D8.woff2) format('woff2');
# unicode-range: U+0100-024F, U+1E00-1EFF, U+20A0-20AB, U+20AD-20CF, U+2C60-2C7F, U+A720-A7FF;
# }
# /* latin */
# @font-face {
# font-family: 'Roboto';
# font-style: normal;
# font-weight: 700;
# src: local('Roboto Bold'), local('Roboto-Bold'), url(https://fonts.gstatic.com/s/roboto/v16/d-6IYplOFocCacKzxwXSOJBw1xU1rKptJj_0jans920.woff2) format('woff2');
# unicode-range: U+0000-00FF, U+0131, U+0152-0153, U+02C6, U+02DA, U+02DC, U+2000-206F, U+2074, U+20AC, U+2212, U+2215;
# }
# .modal-frame, .modal-frame * {
#   font-family: Roboto, Open Sans, Helvetica, Arial, sans-serif !important;
# }
# div.user-profile-modal.modal-wrap > div > div.profile-preview.scrollable-wrap .edit-box.edit-user-settings .input-field:nth-child(3) {
# 	display: none;
# }
# div.user-profile-modal.modal-wrap > div > div.profile-preview.scrollable-wrap > div > div > div.edit-box.edit-user-profile > div:nth-child(1){
# 	display: none;
# }
#
# 		[data-spot-im-class="conversation-root"], [data-spot-im-class="conversation-root"] * {
#     font-family: Roboto, Open Sans, Helvetica, Arial, sans-serif !important;
# }
#
# @media screen and (max-width: 290px) {
#         /*IPhone portrait and smaller. You can probably stop on 380px*/
#        .spcv_message-actions-container .spcv_message-actions {
#             flex-wrap: wrap;
#             width: 125px;
#         }
#         [data-spot-im-class="vote-links"] {
#             margin-top: 10px;
#  }
#  [data-spot-im-class="message-share-button"] {
#           display: none;
#   }
# .spcv_message-actions {
#        flex-wrap: wrap;
# }
# }</style><style type="text/css">#spcv_conversation#spcv_conversation textarea::placeholder {
#     color: #666666;
# }
# #spcv_conversation#spcv_conversation .spcv_rich-editor .spcv_rich-editor-container {
#     border: thin solid #666666 !important;
# }
# #spcv_conversation#spcv_conversation .spcv_animated-vote .spcv_vote-icon.spcv_inactive {
#     fill: #666666 !important;
# }
# #spcv_conversation#spcv_conversation .spcv_notifications .spcv_indicator .spcv_icon {
# fill: #666666 !important;
# color: #666666 !important;
# }
#
# #spcv_conversation#spcv_conversation .spcv_notifications .spcv_indicator .spcv_icon:hover {
# fill: #666666 !important;
# color: #666666 !important;
# }
#
# #spcv_conversation#spcv_conversation .spcv_show-more-replies .spcv_show-more-replies-button {
# color: #666666;
# }
# #spcv_conversation#spcv_conversation .spcv_footer-link, #spcv_conversation#spcv_conversation .spcv_site-link  {
# color: #666666;
# }
# #spcv_conversation#spcv_conversation .spcv_location {
#      color: #666666;
# }
# #spcv_conversation#spcv_conversation .spcv_message-reply , #spcv_conversation#spcv_conversation .spcv_message-share-link , #spcv_conversation#spcv_conversation .spcv_down-votes, #spcv_conversation#spcv_conversation .spcv_up-votes, #spcv_conversation#spcv_conversation .spcv_votes-count,#spcv_conversation#spcv_conversation .spcv_message-report {
#      color: #666666;
# }
# #spcv_conversation#spcv_conversation .spcv_message-details , #spcv_conversation#spcv_conversation .spcv_message-details .spcv_reply-to .spcv_username{
#      color: #666666;
# }
#
#
# #spcv_conversation#spcv_conversation .spcv_notifications .spcv_indicator.spcv_active .spcv_icon, #spcv_conversation#spcv_conversation .spcv_notifications .spcv_indicator:hover .spcv_icon {
# fill: #666666 !important;
# }
#
# #spcv_conversation#spcv_conversation .spcv_sort-menu {
#      color: #666666;
# }
# #spcv_conversation#spcv_conversation .spcv_sort-menu .spcv_sort-by {
#      color: #666666;
# }
# #spcv_conversation#spcv_conversation .spcv_current-user-menu.spcv_text-trigger .spcv_wrapper>* {
#     color: #666666;
# }
# #spcv_conversation#spcv_conversation .spcv_badge {
#   color: #666666 !important;
# };
#
# [data-spot-im-class="set-moderation-item"] {
#     display: none !important;
# };
#
# [data-spot-im-class="settings-item"]{
# 		display: none !important;
# };
#
# [data-spot-im-class="rich-editor-send-button"] span{
#  pointer-events:none;
# };
#
# #root > div > div.user-profile-modal.modal-wrap > div > div.top-navigation > div > div.user-menu > div.tooltip.open.user-dropdown > div > ul > li:nth-child(2){
# 	    display: none !important;
# };
#
# 	/* cyrillic-ext */
# @font-face {
# font-family: 'Roboto';
# font-style: normal;
# font-weight: 400;
# src: local('Roboto'), local('Roboto-Regular'), url(https://fonts.gstatic.com/s/roboto/v16/sTdaA6j0Psb920Vjv-mrzH-_kf6ByYO6CLYdB4HQE-Y.woff2) format('woff2');
# unicode-range: U+0460-052F, U+20B4, U+2DE0-2DFF, U+A640-A69F;
# }
# /* cyrillic */
# @font-face {
# font-family: 'Roboto';
# font-style: normal;
# font-weight: 400;
# src: local('Roboto'), local('Roboto-Regular'), url(https://fonts.gstatic.com/s/roboto/v16/uYECMKoHcO9x1wdmbyHIm3-_kf6ByYO6CLYdB4HQE-Y.woff2) format('woff2');
# unicode-range: U+0400-045F, U+0490-0491, U+04B0-04B1, U+2116;
# }
# /* greek-ext */
# @font-face {
# font-family: 'Roboto';
# font-style: normal;
# font-weight: 400;
# src: local('Roboto'), local('Roboto-Regular'), url(https://fonts.gstatic.com/s/roboto/v16/tnj4SB6DNbdaQnsM8CFqBX-_kf6ByYO6CLYdB4HQE-Y.woff2) format('woff2');
# unicode-range: U+1F00-1FFF;
# }
# /* greek */
# @font-face {
# font-family: 'Roboto';
# font-style: normal;
# font-weight: 400;
# src: local('Roboto'), local('Roboto-Regular'), url(https://fonts.gstatic.com/s/roboto/v16/_VYFx-s824kXq_Ul2BHqYH-_kf6ByYO6CLYdB4HQE-Y.woff2) format('woff2');
# unicode-range: U+0370-03FF;
# }
# /* vietnamese */
# @font-face {
# font-family: 'Roboto';
# font-style: normal;
# font-weight: 400;
# src: local('Roboto'), local('Roboto-Regular'), url(https://fonts.gstatic.com/s/roboto/v16/NJ4vxlgWwWbEsv18dAhqnn-_kf6ByYO6CLYdB4HQE-Y.woff2) format('woff2');
# unicode-range: U+0102-0103, U+1EA0-1EF9, U+20AB;
# }
# /* latin-ext */
# @font-face {
# font-family: 'Roboto';
# font-style: normal;
# font-weight: 400;
# src: local('Roboto'), local('Roboto-Regular'), url(https://fonts.gstatic.com/s/roboto/v16/Ks_cVxiCiwUWVsFWFA3Bjn-_kf6ByYO6CLYdB4HQE-Y.woff2) format('woff2');
# unicode-range: U+0100-024F, U+1E00-1EFF, U+20A0-20AB, U+20AD-20CF, U+2C60-2C7F, U+A720-A7FF;
# }
# /* latin */
# @font-face {
# font-family: 'Roboto';
# font-style: normal;
# font-weight: 400;
# src: local('Roboto'), local('Roboto-Regular'), url(https://fonts.gstatic.com/s/roboto/v16/oMMgfZMQthOryQo9n22dcuvvDin1pK8aKteLpeZ5c0A.woff2) format('woff2');
# unicode-range: U+0000-00FF, U+0131, U+0152-0153, U+02C6, U+02DA, U+02DC, U+2000-206F, U+2074, U+20AC, U+2212, U+2215;
# }
# /* cyrillic-ext */
# @font-face {
# font-family: 'Roboto';
# font-style: normal;
# font-weight: 700;
# src: local('Roboto Bold'), local('Roboto-Bold'), url(https://fonts.gstatic.com/s/roboto/v16/77FXFjRbGzN4aCrSFhlh3oX0hVgzZQUfRDuZrPvH3D8.woff2) format('woff2');
# unicode-range: U+0460-052F, U+20B4, U+2DE0-2DFF, U+A640-A69F;
# }
# /* cyrillic */
# @font-face {
# font-family: 'Roboto';
# font-style: normal;
# font-weight: 700;
# src: local('Roboto Bold'), local('Roboto-Bold'), url(https://fonts.gstatic.com/s/roboto/v16/isZ-wbCXNKAbnjo6_TwHToX0hVgzZQUfRDuZrPvH3D8.woff2) format('woff2');
# unicode-range: U+0400-045F, U+0490-0491, U+04B0-04B1, U+2116;
# }
# /* greek-ext */
# @font-face {
# font-family: 'Roboto';
# font-style: normal;
# font-weight: 700;
# src: local('Roboto Bold'), local('Roboto-Bold'), url(https://fonts.gstatic.com/s/roboto/v16/UX6i4JxQDm3fVTc1CPuwqoX0hVgzZQUfRDuZrPvH3D8.woff2) format('woff2');
# unicode-range: U+1F00-1FFF;
# }
# /* greek */
# @font-face {
# font-family: 'Roboto';
# font-style: normal;
# font-weight: 700;
# src: local('Roboto Bold'), local('Roboto-Bold'), url(https://fonts.gstatic.com/s/roboto/v16/jSN2CGVDbcVyCnfJfjSdfIX0hVgzZQUfRDuZrPvH3D8.woff2) format('woff2');
# unicode-range: U+0370-03FF;
# }
# /* vietnamese */
# @font-face {
# font-family: 'Roboto';
# font-style: normal;
# font-weight: 700;
# src: local('Roboto Bold'), local('Roboto-Bold'), url(https://fonts.gstatic.com/s/roboto/v16/PwZc-YbIL414wB9rB1IAPYX0hVgzZQUfRDuZrPvH3D8.woff2) format('woff2');
# unicode-range: U+0102-0103, U+1EA0-1EF9, U+20AB;
# }
# /* latin-ext */
# @font-face {
# font-family: 'Roboto';
# font-style: normal;
# font-weight: 700;
# src: local('Roboto Bold'), local('Roboto-Bold'), url(https://fonts.gstatic.com/s/roboto/v16/97uahxiqZRoncBaCEI3aW4X0hVgzZQUfRDuZrPvH3D8.woff2) format('woff2');
# unicode-range: U+0100-024F, U+1E00-1EFF, U+20A0-20AB, U+20AD-20CF, U+2C60-2C7F, U+A720-A7FF;
# }
# /* latin */
# @font-face {
# font-family: 'Roboto';
# font-style: normal;
# font-weight: 700;
# src: local('Roboto Bold'), local('Roboto-Bold'), url(https://fonts.gstatic.com/s/roboto/v16/d-6IYplOFocCacKzxwXSOJBw1xU1rKptJj_0jans920.woff2) format('woff2');
# unicode-range: U+0000-00FF, U+0131, U+0152-0153, U+02C6, U+02DA, U+02DC, U+2000-206F, U+2074, U+20AC, U+2212, U+2215;
# }
# .modal-frame, .modal-frame * {
#   font-family: Roboto, Open Sans, Helvetica, Arial, sans-serif !important;
# }
# div.user-profile-modal.modal-wrap > div > div.profile-preview.scrollable-wrap .edit-box.edit-user-settings .input-field:nth-child(3) {
# 	display: none;
# }
# div.user-profile-modal.modal-wrap > div > div.profile-preview.scrollable-wrap > div > div > div.edit-box.edit-user-profile > div:nth-child(1){
# 	display: none;
# }
#
# 		[data-spot-im-class="conversation-root"], [data-spot-im-class="conversation-root"] * {
#     font-family: Roboto, Open Sans, Helvetica, Arial, sans-serif !important;
# }
#
# @media screen and (max-width: 290px) {
#         /*IPhone portrait and smaller. You can probably stop on 380px*/
#        .spcv_message-actions-container .spcv_message-actions {
#             flex-wrap: wrap;
#             width: 125px;
#         }
#         [data-spot-im-class="vote-links"] {
#             margin-top: 10px;
#  }
#  [data-spot-im-class="message-share-button"] {
#           display: none;
#   }
# .spcv_message-actions {
#        flex-wrap: wrap;
# }
# }</style><link href="https://fonts.googleapis.com/css?family=Open+Sans:300,400,600" id="spotim-login-modal-open-sans-style" rel="stylesheet"/></head>
# <body class="fn article-single" data-n-head="class"><div data-show="1" id="welcome-ovr"></div>
# <div id="__nuxt"><div id="__layout"><div class="wrapper" id="wrapper"><div class="notification-banner" data-banner-type="ccpa"> <div class="notification-banner-inner"> <span class="notification-banner-text">By using this site, you agree to our <a href="https://www.foxnews.com/privacy-policy">Privacy Policy</a> and our <a href="https://www.foxnews.com/terms-of-use">Terms of Use</a>.</span> <a class="close" href="#">Close</a> </div></div><header class="site-header"><div class="branding"><a class="logo" href="https://www.foxnews.com/">Fox News</a><div class="current-time hide"><span class="time"></span><span class="zone"></span></div></div><div class="nav-row nav-row-upper"><div class="inner"><div class="primary-nav tablet-desktop"><nav aria-label="main navigation" id="main-nav"><ul><li class="menu-news"><a href="https://www.foxnews.com/us">U.S.</a></li><li class="menu-politics"><a href="https://www.foxnews.com/politics">Politics</a></li><li class="menu-media"><a href="https://www.foxnews.com/media">Media</a></li><li class="menu-opinion"><a href="https://www.foxnews.com/opinion">Opinion</a></li><li class="menu-business"><a href="https://www.foxbusiness.com">Business</a></li><li class="menu-entertainment"><a href="https://www.foxnews.com/entertainment">Entertainment</a></li><li class="menu-sports"><a href="https://www.foxnews.com/sports">Sports</a></li><li class="menu-lifestyle"><a href="https://www.foxnews.com/lifestyle">Lifestyle</a></li><li class="menu-tv"><a href="https://www.foxnews.com/shows">TV</a></li><li class="menu-fox-nation"><a href="https://www.foxnews.com/shows/fox-nation">Fox Nation</a></li><li class="menu-radio"><a href="https://radio.foxnews.com/podcast">Listen</a></li><li class="menu-more"><a class="js-menu-toggle" href="#">More</a></li></ul></nav></div><div class="meta"><div class="search-toggle tablet-desktop"><a class="js-focus-search" href="#">Expand / Collapse search</a></div><div class="network-access logged-out logged-in" id="account"><div class="user-profile user-login button show"><a class="login" data-omtr-intcmp="hp1navlg" href="#">Login</a></div></div><div class="button watch"><a href="https://video.foxnews.com/v/5614615980001/?#sp=watch-live">Watch TV</a></div><div class="menu mobile"><a aria-label="Mobile Menu" class="js-menu-toggle" href="#">Menu</a></div></div></div></div><div class="nav-row nav-row-lower tablet-desktop"><div class="inner"><div class="secondary-nav"><nav aria-label="hot topics" class="hot-topics"><span class="subnav-title">Hot Topics</span><ul class="rotate-items"></ul></nav></div></div></div><div class="expandable-nav"><div class="inner"><div class="search"><div class="search-wrap"><form action="/search-results/search" method="get"><fieldset><input autocomplete="off" class="resp_site_search js-bound" name="q" placeholder="Search foxnews.com" type="text"/><input class="resp_site_submit" type="submit" value="Search"/></fieldset></form></div></div></div><div class="section-nav"><div class="inner"><nav aria-label="Coronavirus" class="mobile"><h6 class="nav-title"><a aria-label="Coronavirus" href="https://www.foxnews.com/category/health/infectious-disease/coronavirus">Coronavirus</a></h6><ul></ul></nav><nav aria-label="U.S."><h6 class="nav-title"><a aria-label="U.S." href="https://www.foxnews.com/us">U.S.</a></h6><ul><li class="nav-item"><a aria-label="U.S. - Crime" href="https://www.foxnews.com/category/us/crime">Crime</a></li><li class="nav-item"><a aria-label="U.S. - Military" href="https://www.foxnews.com/category/us/military">Military</a></li><li class="nav-item"><a aria-label="U.S. - Education" href="https://www.foxnews.com/category/us/education">Education</a></li><li class="nav-item"><a aria-label="U.S. - Terror" href="https://www.foxnews.com/category/us/terror">Terror</a></li><li class="nav-item"><a aria-label="U.S. - Immigration" href="https://www.foxnews.com/category/us/immigration">Immigration</a></li><li class="nav-item"><a aria-label="U.S. - Economy" href="https://www.fox ...
#         About
#       </h6><ul><li class="nav-item"><a aria-label="About - Contact Us" href="https://www.foxnews.com/contact">Contact Us</a></li><li class="nav-item"><a aria-label="About - Careers" href="https://foxcareers.com/Search/SearchResults?brand=Fox%20News%20Careers">Careers</a></li><li class="nav-item"><a aria-label="About - Fox Around the World" href="https://www.foxnews.com/foxaroundtheworld/">Fox Around the World</a></li><li class="nav-item"><a aria-label="About - Advertise With Us" href="mailto:adsales@foxnews.com?subject=Advertising%20Inquiry">Advertise With Us</a></li><li class="nav-item"><a aria-label="About - Media Relations" href="https://press.foxnews.com/media-contacts/">Media Relations</a></li><li class="nav-item"><a aria-label="About - Corporate Information" href="https://press.foxnews.com/">Corporate Information</a></li><li class="nav-item"><a aria-label="About - Compliance" href="https://www.foxnews.com/compliance">Compliance</a></li><li class="nav-item"><a aria-label="About - Supplier Diversity" href="https://supplierdiversity.foxnews.com/">Supplier Diversity</a></li></ul></nav><nav aria-label="Other"><h6 class="nav-title">
#         Other
# ...
# <script type="text/javascript"> (function(FNC){ if (FNC.Loader) { FNC.Loader.init(); } }(window.FNC || {})); </script><script defer="defer" src="https://static.foxnews.com/static/isa/app/lib/VisitorAPI.js" type="text/javascript"></script><script defer="defer" src="https://static.foxnews.com/static/isa/app/lib/new-relic/script.fn.js" type="text/javascript"></script><script defer="defer" src="//global.fncstatic.com/static/v/all/js/ads.js" type="text/javascript"></script><script defer="defer" src="//js.taplytics.com/jssdk/34c3ab59aa2e43688b7e00293b792632.min.js?adobe_evar=eVar65&amp;adobe_obj=omtr" type="text/javascript"></script><script defer="defer" src="https://static.foxnews.com/static/isa/app/lib/VisitorAPI.js" type="text/javascript"></script><script defer="defer" src="https://static.foxnews.com/static/isa/app/lib/omtr_code.js" type="text/javascript"></script>
# <script src="https://ats.rlcdn.com/ats.js"></script><div id="criteo-tags-div" style="display: none;"></div><iframe class="aamIframeLoaded" id="destination_publishing_iframe_foxnews_0" sandbox="allow-scripts allow-same-origin" src="https://foxnews.demdex.net/dest5.html?d_nsid=0#https%3A%2F%2Fwww.foxnews.com%2Fpolitics%2Fscott-nevins-tim-scott-uncle-tom-tweet-board-membership" style="display: none; width: 0px; height: 0px;" title="Adobe ID Syncing iFrame"></iframe><iframe name="googlefcPresent" style="display: none; width: 0px; height: 0px; border: none; z-index: -1000; left: -1000px; top: -1000px;"></iframe><div id="batBeacon706106189203" style="width:0px; height:0px; display:none; visibility:hidden;"><img alt="" height="0" id="batBeacon652885230780" src="https://bat.bing.com/action/0?ti=5739759&amp;Ver=2&amp;mid=ed99cd5e-8f8e-4cba-a698-03a8f0f62cca&amp;sid=e82e1f10ad3611eb8ddf81046de81c22&amp;vid=e82e5f90ad3611eb8c792fd6ee038a67&amp;vids=1&amp;pi=1200101525&amp;lg=en-US&amp;sw=1536&amp;sh=864&amp;sc=24&amp;tl=Comedian%20scrubs%20board%20membership%20from%20social%20media%20bios%20after%20racist%20tweet%20targeting%20Tim%20Scott%20%7C%20Fox%20News&amp;p=https%3A%2F%2Fwww.foxnews.com%2Fpolitics%2Fscott-nevins-tim-scott-uncle-tom-tweet-board-membership&amp;r=&amp;lt=18837&amp;evt=pageLoad&amp;msclkid=N&amp;sv=1&amp;rn=69054" style="width:0px; height:0px; display:none; visibility:hidden;" width="0"/></div><script src="//platform.twitter.com/widgets.js"></script><iframe name="googlefcInactive" src="about:blank" style="display: none; width: 0px; height: 0px; border: none; z-index: -1000; left: -1000px; top: -1000px;"></iframe><iframe name="googlefcLoaded" src="about:blank" style="display: none; width: 0px; height: 0px; border: none; z-index: -1000; left: -1000px; top: -1000px;"></iframe><iframe allowtransparency="true" frameborder="0" scrolling="no" src="https://platform.twitter.com/widgets/widget_iframe.06c6ee58c3810956b7509218508c7b56.html?origin=https%3A%2F%2Fwww.foxnews.com" style="display: none;" title="Twitter settings iframe"></iframe><iframe allowfullscreen="true" allowtransparency="true" frameborder="0" id="rufous-sandbox" scrolling="no" style="position: absolute; visibility: hidden; display: none; width: 0px; height: 0px; padding: 0px; border: none;" title="Twitter analytics iframe"></iframe><script async="" src="https://s.yimg.com/dy/ads/readmo.js" type="text/javascript"></script><script async="" class="processed" data-page-id="24acd6b52057400a944962c055cf5916" data-space-id="1197809846" src="https://s.yimg.com/dy/readmo-pixel.js" type="text/javascript"></script><script async="" src="https://s.yimg.com/ss/rapid3.js"></script><iframe src="https://my.foxnews.com/xd-channel.html?_x_auth=foxid&amp;" style="display: none;"></iframe><iframe id="newsletter-ifr-comm" src="//www.foxnews.com/portal/newsalertsubscribe-xdcomm" style="width:0;height:0;display:none;"></iframe><script async="" src="https://launcher.spot.im/spot/sp_ANQXRpqH"></script><iframe id="frame-template" src="//static.foxnews.com/static/orion/scripts/core/templates/app/iframe.html?v=20210429220719" style="display: none; opacity: 0; width: 0px; height: 0px;"></iframe><div class="ad gam-inst" data-ad-slot-empty="1" data-ad-slot-rendered="1" data-google-query-id="CNqCguihsfACFUyKAQodW78CQA" id="desk-interstitial-1x1" style="display: none;"><div id="google_ads_iframe_/4145/fnc/desk/art/pol/int_0__container__" style="border: 0pt none; width: 1px; height: 1px;"></div></div><script charset="UTF-8" src="https://static-cdn.spot.im/production/launcher/tags/v2.53.5/vendor/vendor-bundle.js" type="text/javascript"></script><style data-spot-im-style="true" spotim-global-css-vars="">
#     :root {
#       --spotim-font-family-default: var(--spotim-font-family);--spotim-layer-background-color: var(--spotim-overlay-background-color);--spotim-action-font-weight: normal;--spotim-ads-text-color: #373e44;--spotim-border-color: #e3e3e3;--spotim-border-color-muted: #00000014;--spotim-border-radius-buttons: var(--spotim-border-radius-medium);--spotim-border-radius-inputs: var(--spotim-border-radius-small);--spotim-border-radius-medium: 6px;--spotim-border-radius-modals: var(--spotim-border-radius-small);--spotim-border-radius-popovers: var(--spotim-border-radius-small);--spotim-border-radius-small: 4px;--spotim-box-shadow-medium: 0 2px 15px 0 rgba(0, 0, 0, 0.1);--spotim-brand-color: #003365;--spotim-brand-text-color: white;--spotim-card-background-color: white;--spotim-color-badge: var(--spotim-brand-color);--spotim-color-community-question: var(--spotim-color-scheme-l6);--spotim-color-scheme-g1: #ffffff;--spotim-color-scheme-g2: #000000;--spotim-color-scheme-g3: #35b940;--spotim-color-scheme-g4: #db3737;--spotim-color-scheme-g5: #3968ff;--spotim-color-scheme-l1: rgba(var(--spotim-color-scheme-l6-rgb, 7,7,7), 0.05);--spotim-color-scheme-l2: rgba(var(--spotim-color-scheme-l6-rgb, 7,7,7), 0.1);--spotim-color-scheme-l3: rgba(var(--spotim-color-scheme-l6-rgb, 7,7,7), 0.2);--spotim-color-scheme-l4: rgba(var(--spotim-color-scheme-l6-rgb, 7,7,7), 0.3);--spotim-color-scheme-l5: #666666;--spotim-color-scheme-l6: #070707;--spotim-color-scheme-l6-rgb: 7,7,7;--spotim-content-loader-primary-color: #f3f3f3;--spotim-content-loaders-secondary-color: #dddddd;--spotim-conversation-background-color: transparent;--spotim-conversation-max-width: 700px;--spotim-danger-color: #db3737;--spotim-extract-background-color: #ffffff;--spotim-font-family: Open Sans, Open Sans Hebrew, Arial;--spotim-font-family-action: var(--spotim-font-family);--spotim-font-family-badge: var(--spotim-font-family);--spotim-font-family-buttons: var(--spotim-font-family);--spotim-font-family-comments-count: var(--spotim-font-family-t4);--spotim-font-family-community-question: Open Sans, Open Sans Hebrew, Arial;--spotim-font-family-date-format: var(--spotim-font-family);--spotim-font-family-product-header: Open Sans, Open Sans Hebrew, Arial;--spotim-font-family-product-subheader: Open Sans, Open Sans Hebrew, Arial;--spotim-font-family-t1: var(--spotim-font-family);--spotim-font-family-t2: var(--spotim-font-family);--spotim-font-family-t3: var(--spotim-font-family);--spotim-font-family-t4: var(--spotim-font-family);--spotim-font-family-t5: var(--spotim-font-family);--spotim-font-family-t6: var(--spotim-font-family);--spotim-font-family-username: var(--spotim-font-family);--spotim-font-size-action: var(--spotim-font-size-medium);--spotim-font-size-badge: 9px;--spotim-font-size-buttons: var(--spotim-font-size-medium);--spotim-font-size-comments-count: var(--spotim-font-size-t4);--spotim-font-size-community-question: 24px;--spotim-font-size-date-format: var(--spotim-font-size-small);--spotim-font-size-large: 16px;--spotim-font-size-medium: 14px;--spotim-font-size-message-actions: 14px;--spotim-font-size-product-header: 24px;--spotim-font-size-product-subheader: 16px;--spotim-font-size-small: 13px;--spotim-font-size-t1: 24px;--spotim-font-size-t2: 20px;--spotim-font-size-t3: 18px;--spotim-font-size-t4: 15px;--spotim-font-size-t5: 13px;--spotim-font-size-t6: 12px;--spotim-font-size-user-image: 15.6px;--spotim-font-size-username: var(--spotim-font-size-medium);--spotim-font-size-x-large: 24px;--spotim-font-size-x-small: 11px;--spotim-font-size-xx-large: 27px;--spotim-font-size-xx-small: 9px;--spotim-font-style-community-question: italic;--spotim-font-weight-bold: bold;--spotim-font-weight-comments-count: var(--spotim-font-weight-t4);--spotim-font-weight-community-question: 400;--spotim-font-weight-normal: 400;--spotim-font-weight-product-header: bold;--spotim-font-weight-product-subheader: 400;--spotim-font-weight-semibold: 600;--spotim-font-weight-username: var(--spotim-font-weight-bold) ...
#     }</style><div data-spot-im-shadow-host="conversation conversation-survey @spotim/ui-components @spotim/ads @spotim/user-image feed @spotim/entities @spotim/content-entities @spotim/user-info @spotim/rich-editor @spotim/toast-provider @spotim/svg-provider @spotim/notifications-bell notifications @spotim/message live-blog" open-web-ui-components-menus=""></div><script charset="UTF-8" src="https://static-cdn.spot.im/production/conversation-page/tags/v2.2.13/conversation-page-bundle.js" type="text/javascript"></script><script charset="UTF-8" src="https://static-cdn.spot.im/production/conversation/tags/v3.33.14/conversation-bundle.js" type="text/javascript"></script><script charset="UTF-8" src="https://static-cdn.spot.im/production/broadcast/tags/v1.1.0/broadcast-fetcher-bundle.js" type="text/javascript"></script><script charset="UTF-8" src="https://static-cdn.spot.im/production/conversation-survey/tags/v0.3.3/conversation-survey.js" type="text/javascript"></script><script charset="UTF-8" src="https://static-cdn.spot.im/production/messages-count/tags/v1.0.0/messages-count-bundle.js" type="text/javascript"></script><script charset="UTF-8" src="https://static-cdn.spot.im/production/registration/tags/v1.15.5/registration-bundle.js" type="text/javascript"></script><iframe src="https://s.amazon-adsystem.com/iu3?cm3ppd=1&amp;d=dtb-pub&amp;csif=t&amp;dl=n-emx_n-vmg_dm_dmx_3lift" style="display: none;"></iframe><iframe id="google_osd_static_frame_6345964531115" name="google_osd_static_frame" style="display: none; width: 0px; height: 0px;"></iframe><div open-web-ui-components-non-shadow-dom-menus=""></div><iframe height="0" style="display: none;" title="Criteo DIS iframe" width="0"></iframe><iframe id="criteo-syncframe" src='https://gum.criteo.com/syncframe?topUrl=www.foxnews.com#{"optout":{"value":false,"origin":0},"uid":{"origin":0},"sid":{"origin":0},"origin":"publishertag","version":106,"lwid":{"origin":0},"tld":"foxnews.com","bundle":{"origin":0},"topUrl":"www.foxnews.com","cw":true,"ifa":{"origin":0},"lsw":true}' style="display: none;"></iframe></body><iframe allowtransparency="true" frameborder="0" height="0" hspace="0" id="20e53a94d2e30e9" marginheight="0" marginwidth="0" sandbox="allow-scripts allow-same-origin" scrolling="no" src="https://ads.pubmatic.com/AdServer/js/showad.js#PIX&amp;kdntuid=1&amp;p=158583&amp;us_privacy=1---" style="height:0px;width:0px;display:none;" vspace="0" width="0">
# </iframe><iframe allowtransparency="true" frameborder="0" height="0" hspace="0" id="218972eb06af471" marginheight="0" marginwidth="0" sandbox="allow-scripts allow-same-origin" scrolling="no" src="https://js-sec.indexww.com/um/ixmatch.html" style="height:0px;width:0px;display:none;" vspace="0" width="0">
# </iframe><iframe allowtransparency="true" frameborder="0" height="0" hspace="0" id="22133c84fee99a5" marginheight="0" marginwidth="0" sandbox="allow-scripts allow-same-origin" scrolling="no" src="https://acdn.adnxs.com/dmp/async_usersync.html" style="height:0px;width:0px;display:none;" vspace="0" width="0">
# </iframe><iframe allowtransparency="true" frameborder="0" height="0" hspace="0" id="239b1a6a02a891b" marginheight="0" marginwidth="0" sandbox="allow-scripts allow-same-origin" scrolling="no" src="https://eus.rubiconproject.com/usync.html?us_privacy=1---" style="height:0px;width:0px;display:none;" vspace="0" width="0">
# </iframe><iframe allowtransparency="true" frameborder="0" height="0" hspace="0" id="248c4d1008d7758" marginheight="0" marginwidth="0" sandbox="allow-scripts allow-same-origin" scrolling="no" src="https://us-u.openx.net/w/1.0/pd?plm=6&amp;ph=821a7a03-0610-4f16-ae68-93099cfd1a23&amp;gdpr=0&amp;us_privacy=1---" style="height:0px;width:0px;display:none;" vspace="0" width="0">
# </iframe></html>

# %%
FoxData = []
news = soup.find_all('p')
exclude = soup.find('a')
postscript =  soup.find('p',{"class": "copyright"})
copyright = postscript.text
exclude.append(copyright)
subscribe = "You've successfully subscribed to this newsletter!"
exclude.append(subscribe)

for tuple in news: 
    for paragraph in news not in exclude:
        text =paragraph.text
        FoxData.append(text)
        print(text)
print(copyright)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-9fe27995861f> in <module>
#       9
#      10 for tuple in news:
# ---> 11     for paragraph in news not in exclude:
#      12         text =paragraph.text
#      13         FoxData.append(text)
#
# TypeError: 'bool' object is not iterable

# %%
for i in FoxData: 
    if i == copyright:
        FoxData.remove(i)
    elif i == subscribe:
        FoxData.remove(i)
FoxData
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-82dc4ef80f7e> in <module>
# ----> 1 for i in FoxData:
#       2     if i == copyright:
#       3         FoxData.remove(i)
#       4     elif i == subscribe:
#       5         FoxData.remove(i)
#
# NameError: name 'FoxData' is not defined

# %%
Fallondata = []
Comedians = []
title = soup.find_all('div', id='details')
for tuple in title:
    titles = tuple.find('a')['title']
    data = tuple.find('a')['aria-label']
    views = tuple.find('a')['aria-label']
    Fallondata.append(data)
    print(data)

# %%
Fallon_df=[]
title_reg='.+?(?=by)'
reg = ' ([0-9,]+) views$'
time ='(([0-9]+) minute(s)?(, ([0-9]+) second(s)?)?)'
time2 ='([0-9]+ second(s)?)'

for text in Fallondata:
    ret = re.findall(reg, text)
        
    host = "Jimmy Fallon"
    title = re.findall(title_reg, text)[0]
    try:
        length = re.findall(time, text)[0][0]
    except: # new regex for when videos are less than 1 min long
        length = re.findall(time2, text)[0][0]

    Fallon_df.append({"Title":title, "Host":host, "Video Length": length, "Views": int(ret[0].replace(",", ""))})

    Comedians.append({"Title":title, "Host":host, "Video Length": length, "Views": int(ret[0].replace(",", ""))})

# %%
len(Comedians)

# %%
Fallon_df

# %%
url = 'https://www.youtube.com/c/LateNightSeth/videos'
browser.visit(url)

# %%
html = browser.html
Meyerssoup = BeautifulSoup(html, 'html.parser')
Meyerssoup

# %%
Meyersdata =[]
title = Meyerssoup.find_all('div', id='details')
for tuple in title:
    titles = tuple.find('a')['title']
    data = tuple.find('a')['aria-label']
    views = tuple.find('a')['aria-label']
    Meyersdata.append(data)
    Meyersdata

# %%
len(Comedians)

# %%
Meyersdata

# %%
title_reg='.+?(?=by)'
reg = ' ([0-9,]+) views$'
time ='(([0-9]+) minute(s)?(, ([0-9]+) second(s)?)?)'
time2 ='([0-9]+ second(s)?)'
Meyers_df = []
for text in Meyersdata:
    ret = re.findall(reg, text)
        
    host = "Seth Meyers"
    title = re.findall(title_reg, text)[0]
    try:
        length = re.findall(time, text)[0][0]
    except: # new regex for when videos are less than 1 min long
        length = re.findall(time2, text)[0][0]

    Meyers_df.append({"Title":title, "Host":host, "Video Length": length, "Views": int(ret[0].replace(",", ""))})

    Comedians.append({"Title":title, "Host":host, "Video Length": length, "Views": int(ret[0].replace(",", ""))})

# %%
len(Comedians)

# %%
url = 'https://www.youtube.com/c/TheDailyShow/videos'
browser.visit(url)

# %%
html = browser.html
Noahsoup = BeautifulSoup(html, 'html.parser')
Noahsoup

# %%
Noahdata =[]
title = Noahsoup.find_all('div', id='details')
for tuple in title:
    titles = tuple.find('a')['title']
    data = tuple.find('a')['aria-label']
    views = tuple.find('a')['aria-label']
    Noahdata.append(data)

    print(data)

# %%
len(Comedians)

# %%
Noah_df = []

reg = ' ([0-9,]+) views$'
time ='(([0-9]+) minute(s)?(, ([0-9]+) second(s)?)?)'
time2 ='([0-9]+ second(s)?)'
Meyers_df = []
for text in Noahdata:
    ret = re.findall(reg, text)
        
    host = "Trevor Noah"
    title = re.findall(title_reg, text)[0]
    try:
        length = re.findall(time, text)[0][0]
    except: # new regex for when videos are less than 1 min long
        length = re.findall(time2, text)[0][0]

    Noah_df.append({"Title":title, "Host":host, "Video Length": length, "Views": int(ret[0].replace(",", ""))})

    Comedians.append({"Title":title, "Host":host, "Video Length": length, "Views": int(ret[0].replace(",", ""))})

# %%
Noah_df

# %%
url = 'https://www.youtube.com/jkl/videos'
browser.visit(url)

# %%
html = browser.html
Kimmelsoup = BeautifulSoup(html, 'html.parser')
Kimmelsoup

# %%
Kimmeldata =[]
title = Kimmelsoup.find_all('div', id='details')
for tuple in title:
    titles = tuple.find('a')['title']
    data = tuple.find('a')['aria-label']
    views = tuple.find('a')['aria-label']
    Kimmeldata.append(data)
    

    print(data)

# %%
Kimmel_df=[]
reg = ' ([0-9,]+) views$'
time ='(([0-9]+) minute(s)?(, ([0-9]+) second(s)?)?)'
time2 ='([0-9]+ second(s)?)'

for text in Kimmeldata:
    ret = re.findall(reg, text)
        
    host = "Jimmy Kimmel"
    title = re.findall(title_reg, text)[0][0]
    try:
        length = re.findall(time, text) [0][0]
        
    except: # new regex for when videos are less than 1 min long
        length = re.findall(time2, text)

    Kimmel_df.append({"Title":title, "Host":host, "Video Length": length, "Views": int(ret[0].replace(",", ""))})

    Comedians.append({"Title":title, "Host":host, "Video Length": length, "Views": int(ret[0].replace(",", ""))})
Kimmel_df

# %%
length = re.findall(time, text)

# %%
len(Comedians)

# %%
Kimmel_df

# %%
url = 'https://www.youtube.com/c/ColbertLateShow/videos'
browser.visit(url)

# %%
html = browser.html
Colbertsoup = BeautifulSoup(html, 'html.parser')
Colbertsoup

# %%
Colbertdata =[]
title =Colbertsoup.find_all('div', id='details')
for tuple in title:
    titles = tuple.find('a')['title']
    data = tuple.find('a')['aria-label']
    views = tuple.find('a')['aria-label']
    Colbertdata.append(data)
    

    print(data)

# %%
len(Colbertdata)

# %%
Colbert_df=[]
reg = ' ([0-9,]+) views$'
time ='(([0-9]+) minute(s)?(, ([0-9]+) second(s)?)?)'
time2 ='([0-9]+ second(s)?)'

for text in Colbertdata:
    ret = re.findall(reg, text)
        
    host = "Stephen Colbert"
    title = re.findall(title_reg, text)[0]
    try:
        length = re.findall(time, text)[0][0]
    except: # new regex for when videos are less than 1 min long
        length = re.findall(time2, text)[0][0]

    Colbert_df.append({"Title":title, "Host":host, "Video Length": length, "Views": int(ret[0].replace(",", ""))})

    Comedians.append({"Title":title, "Host":host, "Video Length": length, "Views": int(ret[0].replace(",", ""))})

# %%
Colbert_df

# %%
Comedians_df = pd.DataFrame(Comedians)
Comedians_df

# %%
len(Comedians_df)

# %%
Comedians_df.head()

# %%
Comedians_df.isna().count()

# %%
min_sec = Comedians_df["Video Length"].str.split(", ", expand=True)
min_sec.columns = ["Minutes", "Seconds"]
# min_sec["Minutes"] = min_sec["Minutes"].str.replace(" minutes", "").str.replace(" minute", "")
min_sec["Minutes"] = min_sec["Minutes"].str.replace("[^\d]*", "")
# .astype("int")
# min_sec["Seconds"] = min_sec["Seconds"].str.replace(" seconds", "").str.replace(" second", "")
min_sec["Seconds"] = min_sec["Seconds"].str.replace("[^\d]*", "")
min_sec["Minutes"].fillna("0")
min_sec["Seconds"].fillna("0")
min_sec["Minutes"] = min_sec["Minutes"].astype("float")
min_sec["Seconds"] = min_sec["Seconds"].astype("float")
# min_sec["time"] = (min_sec["Minutes"]*60)+min_sec["Seconds"]

# %%
Comedians_df["time"] = (min_sec["Minutes"]*60)+min_sec["Seconds"]

# %%
Comedians_df.dtypes

# %%
# seconds = [int(y["Minutes"])*60 + int(y["Seconds"]) for x, y in min_sec.iterrows()]
# seconds

# %%
engine = create_engine('postgresql://postgres:{password}@localhost:5433/Corporate_DB'.format(password=PGpassword))
connection = engine.connect()

# %%
Comedians_df.to_sql(name='Comedians', con=engine, if_exists='replace', index=False)

# %%
pd.read_sql_query('SELECT * FROM "Comedians"', con=engine).head()
